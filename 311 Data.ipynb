# %%
# from pandas import *
# from numpy import *
# from datetime import *

import pandas as pd
import numpy as np
import datetime as dt

# %%
#Locates, opens and reads the file

f = pd.read_csv('C:/Users/Tamara/Documents/Python Scripts/311_adjusted.csv',parse_dates=True)

# %%
f.shape #returns the number of columns and rows in the file
# Out:
# (952316, 9)

# %%
f.columns #returns the names of all columns in the dataframe
# Out:
# Index(['UNIQUE_ID', 'DATE', 'TIME', 'DATE_TIME', 'AGENCY', 'AGENCY_NAME',
#        'INQUIRY_NAME', 'BRIEF_DESCRIPTION', 'CALL_RESOLUTION'],
#       dtype='object')

# %%
#f1 = f[['UNIQUE_ID','DATE','TIME','AGENCY','AGENCY_NAME','INQUIRY_NAME']]
#ddt = f[['DATE']]
#f2 = f1.pivot_table(values='UNIQUE_ID', index='AGENCY',columns='DATE', aggfunc='count',fill_value='')

# %%
#takes the column DATE, converts it into a Datetime object and puts it into a new column caled yr
f['yr'] = pd.to_datetime(f.DATE)  

#extracts the year from the yr column and puts it into a new column called years
f['years'] = f.yr.dt.year  

#extracts the month from the yr column and saves it into a new column called months
f['months'] = f.yr.dt.month 

#f['month_name'] = f.yr.dt.month_name

# %%
#f1.yr.dt.year
f.head(5)
# Out:
#    UNIQUE_ID       DATE        TIME       DATE_TIME AGENCY  \
# 0   93224272  5/24/2013  9:35:41 AM  5/24/2013 9:35    DEP
# 1   93224273  5/24/2013  9:36:14 AM  5/24/2013 9:36    HHC
# 2   93224274  5/24/2013  9:38:00 AM  5/24/2013 9:38   NYPD
# 3   93224275  5/24/2013  9:40:26 AM  5/24/2013 9:40    DEP
# 4   93224276  5/24/2013  9:42:57 AM  5/24/2013 9:42    DOF
#
#                               AGENCY_NAME  \
# 0  Department of Environmental Protection
# 1        Health and Hospitals Corporation
# 2         New York City Police Department
# 3  Department of Environmental Protection
# 4                   Department of Finance
#
#                                         INQUIRY_NAME  \
# 0                     Catch Basin Clogged or Blocked
# 1                             Find a Public Hospital
# 2                          Illegal Parking Complaint
# 3                                     Noise from Dog
# 4  Parking Ticket Lookup - Ticket or Plate Number...
#
# ...

# %%
summary = f.pivot_table(values='UNIQUE_ID', index='CALL_RESOLUTION',columns='months', aggfunc='count',fill_value='')

# %%
summary
# Out:
# months                          5       6      7  8
# CALL_RESOLUTION
# Agency Closed                2994   14258   5012
# Alert Information Provided   1008    2209   1153
# Appointment                   373    1859    889
# Appt Information Provided      42     262     78
# Away Long Term                          2      1
# Busy Signal                     1      24     11
# CSMS SR                     17053   70956  23095
# Call Dropped                                   1
# Call-Back Notification                  1      1
# Caller Hung Up               1018    4279   1493
# Cancelled Appt                510    2217    790
# Facility Finder               675    2796   1229
# Hot Transfer 911             4401   19106   6773
# Hung Up                                        2
# Incomplete                      1
# Information Provided        46060  213334  87407
# Internal Transfer            8328   43099  17418
# Modified Appt                  39     160     71
# ...

# %%
f['Agency Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3-1\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Agency Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b81f69f22c03> in <module>()
# ----> 1 f['Agency Name']
#
# ...

# %%
#print(f.iloc[:,[0:1])
print(f)
